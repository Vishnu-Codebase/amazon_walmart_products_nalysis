# %% [markdown]
# ##### 1. Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ##### 2. Load Walmart & Amazon Datasets

# %%
walmart= pd.read_csv("walmart_products.csv")
amazon_raw = pd.read_csv(
    "amazon_products.csv",
    engine="python",
    sep=",",
    on_bad_lines="skip"
)


print('amazon-shape:', amazon_raw.shape)
# Out:
# amazon-shape: (1066, 11220)

# %%
# Remove columns with no name
amazon = amazon_raw.loc[:, ~amazon_raw.columns.str.contains("^Unnamed")]

# Remove fully empty columns
amazon = amazon.dropna(axis=1, how="all")

print("After cleaning:", amazon.shape)
# Out:
# After cleaning: (1066, 85)

# %% [markdown]
# ##### 3. Checks shapes

# %%
print("Walmart:", walmart.shape)
print("Amazon:", amazon.shape)
# Out:
# Walmart: (1000, 44)
# Amazon: (1066, 85)

# %% [markdown]
# ##### 4. Inspecting amazon file format

# %%
# View first few lines raw
with open("amazon_products.csv", "r", encoding="utf-8") as f:
    for i in range(5):
        print(f.readline())
# Out:
# title,seller_name,brand,description,initial_price,currency,availability,reviews_count,categories,parent_asin,asin,buybox_seller,number_of_sellers,root_bs_rank,ISBN10,answered_questions,domain,images_count,url,video_count,image_url,item_weight,rating,product_dimensions,seller_id,image,date_first_available,discount,model_number,manufacturer,department,plus_content,upc,video,top_review,final_price_high,final_price,variations,delivery,features,format,buybox_prices,input_asin,ingredients,origin_url,bought_past_month,is_available,root_bs_category,bs_category,bs_rank,badge,subcategory_rank,amazon_choice,images,product_details,prices_breakdown,country_of_origin,from_the_brand,product_description,seller_url,customer_says,sustainability_features,climate_pledge_friendly,videos,other_sellers_prices,downloadable_videos,editorial_reviews,about_the_author,zipcode,coupon,sponsored,store_url,ships_from,city,customers_say,max_quantity_available,variations_values,language,return_policy,inactive_buy_box,buybox_seller_rating,premium_brand,amazon_prime,coupon_description,all_badges,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,, ...
#
# Teamson Home Glazed Vase Floor Freestanding Water Fountain,,Teamson Home,"Turn your home's outdoor area into a relaxing oasis with the Teamson Home Indoor/Outdoor Contemporary Glazed Vase Water Fountain with LED Lights. This outdoor waterfall fountain features a contoured vase design in a glazed red finish for a tranquil and soothing addition to your porch, backyard, or lawn. Constructed from durable polyresin and stone powder, this fountain is weatherproof and rust-resistant. The built-in LED lights keep this fountain illuminated to add a soft glow to your indoor or outdoor space. Relax to the sounds of the water flow as it trickles down from the top of the vase to the reservoir below for a peaceful escape. For convenient setup, the fountain includes a pump and all necessary parts for installation without the need to purchase additional hardware. This fountain measures 15"" x 14.5"" x 32"" to easily fit in almost any outdoor space.",,USD,Currently unavailable. We don't know when or if this item will be back in stock.,0,"[""Home & Kitchen"",""Home Décor Products"",""Indoor Fountains & Accessories"",""Floor-Standing Fountains""]",B0CHJVHBJY,B0CHJVHBJY,,1,,,0,https://www.amazon.com/,1,https://www.amazon.com/Teamson-Home-Glazed-Freestanding-Fountain/dp/B0CHJVHBJY?th=1&psc=1&language=en_US&currency=USD,0,https://m.media-amazon.com/images/I/01RmK+J4pJL._AC_.gif,,0,,ATVPDKIKX0DER,https://m.media-amazon.com/images/I/01RmK+J4pJL._AC_.gif,,,PT-WF0002,Teamson Home,Home & Kitchen,FALSE,,FALSE,,,,,,,,"{""unit_price"":null}",,,,,FALSE,,,,,,FALSE,"[""https://m.media-amazon.com/images/I/01RmK+J4pJL._AC_.gif""]","[{""type"":""Manufacturer"",""value"":""Teamson Home""},{""type"":""ASIN"",""value"":""B0CHJVHBJY""},{""type"":""Item model number"",""value"":""PT-WF0002""}]","{""deal_type"":null,""list_price"":null,""typical_price"":null}",,,,https://www.amazon.com/sp?ie=UTF8&seller=ATVPDKIKX0DER&asin=B0CHJVHBJY,,,FALSE,,,,,,******,,FALSE,,,,"{""keywords"":{""mixed"":null,""negative"":null,""positive"":null},""text"":null}",,,,,"{""price"":null}",,FALSE,FALSE,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,, ...
#
# Christmas Dogs Tumbler | Gift Present Home Decor Decoration,,Generic,"Our Christmas dogs tumbler make the perfect gift not just for Christmas, birthday, Valentine's Day, Mother's or Father's Day. They're great anytime of year. Sure to bring a smile to your face while adding some flare to your day! Images are printed on both sides!! 11 and 15 ounce mugs are ceramic and both microwave and dishwasher safe. 14 oz travel cups and 20oz tumblers are both steel and just dishwasher safe. All items feature vibrant, permanent prints. Great for home decorating, gifts, presents, or just because. Unique and fashionable designs such as this cavalier king charles spaniel santa 2 print are sure to stand out!",,USD,Currently unavailable. We don't know when or if this item will be back in stock.,1,"[""Home & Kitchen"",""Kitchen & Dining"",""Dining & Entertaining"",""Glassware & Drinkware"",""Cups, Mugs, & Saucers"",""Coffee Cups & Mugs""]",B0DJV93L7Z,B0DJTZMGNW,,1,967355,,0,https://www.amazon.com/,6,https://www.amazon.com/Christmas-Tumbler-Present-Decor-Decoration/dp/B0DJTZMGNW?th=1&psc=1&language=en_US&currency=USD,0,https://m.media-amazon.com/images/I/61julAzUUhL._AC_SL1200_.jpg,14 ounces,5,10 x 3 x 3 inches,ATVPDKIKX0DER,https://m.media-amazon.com/images/I/61julAzUUhL._AC_SL1200_.jpg,10-Oct-24,,,,Home & Kitchen,FALSE,,FALSE,,,,,,"[""11 and 15 ounce ceramic mugs are microwave and dishwasher safe | 14 and 20 ounce steel mugs are dishwasher safe"",""Printed and pressed in the USA by small family owned and operated business"",""Images are permanent, won't crack, peel, or fade over time | Bright, vibrant colors, with fun, adorable, and unique designs"",""Check out our shop for other seasonal and fall home and kitchen accessories"",""All products are made to order, if you are not satisfied, we are not satisfied! We love happy customers, so if your product does not meet your expectation, contact us for returns and refunds""]",,"{""unit_price"":null}",,,,,FALSE,Kitchen & Dining,Handmade Kitchen & Dining,12352,,"[{""subcategory_name"":""Handmade Kitchen & Dining"",""subcategory_rank"":12352},{""subcategory_name"":""Mugs"",""subcategory_rank"":30482}]",FALSE,"[""https://m.media-amazon.com/images/I/61julAzUUhL._AC_SL1200_.jpg"",""https://m.media-amazon.com/images/I/6164W1rfozL._AC_SL1200_.jpg"",""https://m.media-amazon.com/images/I/61wwC4TzULL._AC_SL1200_.jpg"",""https://m.media-amazon.com/images/I/61WcnNedtpL._AC_SL1200_.jpg"",""https://m.media-amazon.com/images/I/51mBApzO-+L._AC_SL1200_.jpg"",""https://m.media-amazon.com/images/I/61kPcvlouoL._AC_SL1200_.jpg""]","[{""type"":""Brand"",""value"":""Generic""},{""type"":""Material"",""value"":""Stainless Steel""},{""type"":""Color"",""value"":""Christmas""},{""type"":""Style"",""value"":""Cavalier King Charles Spaniel Santa 2""},{""type"":""Finish Type"",""value"":""Enamel""},{""type"":""Size"",""value"":""Tumbler""},{""type"":""Package Dimensions"",""value"":""10 x 3 x 3 inches""},{""type"":""Item Weight"",""value"":""14 ounces""},{""type"":""ASIN"",""value"":""B0DJTZMGNW""},{""type"":""Customer Reviews"",""value"":""5.05.0 out of 5 stars(1)5.0 out of 5 stars""},{""type"":""Best Sellers Rank"",""value"":""#967,355 in Kitchen & Dining (See Top 100 in Kitchen & Dining)#12,352 in Handmade Kitchen & Dining#30,482 in Mugs""},{""type"":""Date First Available"",""value"":""October 10, 2024""},{""type"":""Brand"",""value"":""Generic""},{""type"":""Material"",""value"":""Stainless Steel""},{""type"":""Color"",""value"":""Christmas""},{""type"":""Style"",""value"":""Cavalier King Charles Spaniel Santa 2""},{""type"":""Finish Type"",""value"":""Enamel""}]","{""deal_type"":null,""list_price"":null,""typical_price"":null}",,,,https://www.amazon.com/sp?ie=UTF8&seller=ATVPDKIKX0DER&asin=B0DJTZMGNW,,,FALSE,,,,,,******,,FALSE,https://www.amazon.com/Handmade/b/ref=bl_dp_s_web_120955898011?ie=UTF8&node=120955898011&field-lbr_brands_browse-bin=Handmade,,,"{""keywords"":{""mixed"":null,""negative"":null,""positive"":null},""t ...
#
# YR gt3-DL Integrated Melamine Board Computer Desk with Drawers Black,,DAVEBELLA,"Welcome [YR]'s Specifications: The item will be divided into two parts. 1. Material: Melamine Board2. Color: Black PartA：1. Desk Dimensions: (27.6 x 20.47 x 3.5)"" / (70 x 52 x 9)cm (L x W x H)2. Weight: 37.48 lbs / 17 kg PartB： 1. Desk Dimensions: (47.2 x 21.7 x 29.5)"" / (120 x 55 x 75)cm (L x W x H)2. Weight: 58.4 lbs / 26.5 kg Package Includes: 1 x Computer Desk The Computer Desk is packed in 2 different boxes. The depvery time copd also be different. Please wait 1-2 more days if you only received 1 package.",,USD,Currently unavailable. We don't know when or if this item will be back in stock.,,"[""Office Products"",""Office Furniture & Lighting"",""Desks & Workstations"",""Computer Workstations""]",,B0B71TSHR8,,,,,,www.amazon.com,6,https://www.amazon.com/dp/B0B71TSHR8?language=en_US&currency=USD,0,https://m.media-amazon.com/images/I/51IOTMlLOmS.__AC_SX300_SY300_QL70_FMwebp_.jpg,163.7 pounds,,,,https://m.media-amazon.com/images/I/51IOTMlLOmS.__AC_SX300_SY300_QL70_FMwebp_.jpg,,,,,,FALSE,,FALSE,,,,,[],"[""1.Pretty integration of high-strength material and nice workmanship"",""2.Durable and stable for supporting certain weight"",""3.Built-in several drawers for holding more gadgets, help to save space in your house"",""4.It is smartly designed with a small desk on the computer desk"",""5.Suitable for teachers, workers, students and businessmen etc.""]",[],"{""sns_price"":{}}",,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,, ...
#
# compartments,mig***mou***,RCA,,25,USD,Only 1 left in stock - order soon.,16,"[""CDs & Vinyl"",""Rock""]",B00413NTD2,B00413NTD2,mightymounts,1,585070,,0,https://www.amazon.com/,3,https://www.amazon.com/compartments-LP-JOSE-FELICIANO/dp/B00413NTD2?th=1&psc=1&language=en_US&currency=USD,0,https://m.media-amazon.com/images/I/61Oafi-mi0L._SL1200_.jpg,,5,12 x 12 x 0.25 inches; 0.01 ounces,A2966FOX1EWRNK,,28-Jul-10,,,RCA,CDs & Vinyl,FALSE,,FALSE,Wow! Thanks for a great transaction! The item was even better than described and it was delivered speedily.  Would definitely buy from this seller again.,,25,,"[""$3.99 delivery October 1 - 8. ""]",,,"{""final_price"":25,""initial_price"":25,""unit_price"":null}",,,,,TRUE,CDs & Vinyl,Rock (CDs & Vinyl),225508,,"[{""subcategory_name"":""Rock (CDs & Vinyl)"",""subcategory_rank"":225508}]",FALSE,"[""https://m.media-amazon.com/images/I/61Oafi-mi0L._SL1200_.jpg"",""https://m.media-amazon.com/images/I/61Oafi-mi0L._SL1200_.jpg"",""https://m.media-amazon.com/images/I/513p+aSLstL._SL1200_.jpg""]","[{""type"":""Package Dimensions"",""value"":""12 x 12 x 0.25 inches; 0.01 ounces""},{""type"":""Manufacturer"",""value"":""RCA""},{""type"":""Date First Available"",""value"":""July 28, 2010""},{""type"":""Label"",""value"":""RCA""},{""type"":""ASIN"",""value"":""B00413NTD2""},{""type"":""Best Sellers Rank"",""value"":null},{""type"":""Customer Reviews"",""value"":""16""}]","{""deal_type"":null,""list_price"":null,""typical_price"":null}",,,,https://www.amazon.com/sp?ie=UTF8&seller=A2966FOX1EWRNK&asin=B00413NTD2,,,FALSE,,"[{""delivery"":""$3.99 delivery October 1 - 8. Details"",""num_of_ratings"":16,""price"":25,""price_per_unit"":null,""seller_name"":""mightymounts"",""seller_rating"":5,""seller_url"":""https://www.amazon.com/gp/aag/main?ie=UTF8&seller=A2966FOX1EWRNK&isAmazonFulfilled=0&asin=B00413NTD2&ref_=olp_merch_name_0"",""ships_from"":""mightymounts"",""unit"":null},{""delivery"":""FREE delivery Thursday, October 2. Details"",""num_of_ratings"":27679,""price"":11.03,""price_per_unit"":null,""seller_name"":""Mr-Magazine"",""seller_rating"":5,""seller_url"":""https://www.amazon.com/gp/aag/main?ie=UTF8&seller=AVXK3OC4ZPJBG&isAmazonFulfilled=0&asin=B00413NTD2&ref_=olp_merch_name_1"",""ships_from"":""Mr-Magazine"",""unit"":null},{""delivery"":""FREE delivery October 2 - 9. Details. Or fastest delivery September 29 - October 2. Details"",""num_of_ratings"":2495,""price"":11.04,""price_per_unit"":null,""seller_name"":""SPRUCEKNOB"",""seller_rating"":4.5,""seller_url"":""https://www.amazon.com/gp/aag/main?ie=UTF8&seller=AC4DPV0MXYH2F&isAmazonFulfilled=0&asin=B00413NTD2&ref_=olp_merch_name_2"",""ships_from"":""SPRUCEKNOB"",""unit"":null},{""delivery"":""$5.67 delivery September 29 - October 2. Details. Or fastest delivery September 26 - 30. Details"",""num_of_ratings"":250,""price"":5.98,""price_per_unit"":null,""seller_name"":""DoughRayMedia"",""seller_rating"":5,""seller_url"":""https://www.amazon.com/gp/aag/main?ie=UTF8&seller=A15X6FIYSFVFDB&isAmazonFulfilled=0&asin=B00413NTD2&ref_=olp_merch_name_3"",""ships_from"":""DoughRayMedia"",""unit"":null},{""delivery"":""$3.99 delivery October 1 - 17. Details"",""num_of_ratings"":489,""price"":9.95,""price_per_unit"":null,""seller_name"":""Booklife01"",""seller_rating"":4.5,""seller_url"":""https://www.amazon.com/gp/aag/main?ie=UTF8&seller=A1UTMO8T3TPZ4M&isAmazonFulfilled=0&asin=B00413NTD2&ref_=olp_merch_name_4"",""ships_from"":""Booklife01"",""unit"":null},{""delivery"":""$5.99 delivery October 2 - 3. Details"",""num_of_ratings"":538,""price"":7.99,""price_per_unit"":null,""seller_name"":""meowrecords"",""seller_rating"":4.5,""seller_url"":""https://www.amazon.com/gp/aag/main?ie=UTF8&seller=A170FNOZMDSL2M&isAmazonFulfilled=0&asin=B00413NTD2&ref_=olp_merch_name_5"",""ships_from"":""meowrecords"",""unit"":null},{""delivery"":""$4.50 delivery Wednesday, October 1. Details"",""num_of_ratings"":5815,""price"":9.99,""price_per_unit"":null,""seller_name"":""Vortex Music  ...

# %% [markdown]
# ##### Standardize Amazon Columns to Match Walmart

# %%
amazon = amazon.rename(columns={
    "price": "final_price",
    "list_price": "initial_price",
    "product_rating": "rating",
    "product_brand": "brand",
    "product_url": "url",
    "category": "categories",
    "product_description": "description"
})

# %% [markdown]
# ##### 6. Select matching columns

# %%
common_cols = [
    "discount",
    "categories",
    "url",
    "initial_price",
    "brand",
    "rating",
    "final_price",
    "currency",
    "upc",
    "description",
    "ingredients"
]

# Keep only existing ones
amazon = amazon[[c for c in common_cols if c in amazon.columns]]
walmart = walmart[[c for c in common_cols if c in walmart.columns]]

# %% [markdown]
# ##### 7. Remove duplicate records

# %%
print("Amazon duplicate columns:", amazon.columns.duplicated().sum())
print("Walmart duplicate columns:", walmart.columns.duplicated().sum())

# Remove duplicate columns from Amazon
amazon = amazon.loc[:, ~amazon.columns.duplicated()]

# Double-check
print("Amazon duplicate columns after fix:", amazon.columns.duplicated().sum())
# Out:
# Amazon duplicate columns: 1
# Walmart duplicate columns: 0
# Amazon duplicate columns after fix: 0

# %% [markdown]
# ##### 7. Add Platform Column

# %%
amazon["platform"] = "Amazon"
walmart["platform"] = "Walmart"
amazon.head(2)
walmart.head(2)
# Out:
#   discount                                         categories  \
# 0      NaN  ["Beauty","Makeup","Eye Makeup","Eye Shadow","...
# 1   $22.92  ["Home","Decor","Curtains & Window Treatments"...
#
#                                                  url  initial_price  \
# 0  https://www.walmart.com/ip/Laura-Mercier-Cavia...            NaN
# 1  https://www.walmart.com/ip/Exultantex-Grey-Bla...           70.8
#
#            brand  rating  final_price currency           upc  \
# 0  Laura Mercier     4.0         22.9      USD  7.361500e+11
# 1     Exultantex     4.6         47.9      USD  7.710780e+11
#
#                                          description  \
# 0  Laura Mercier Caviar Stick Eye Color Sugar Fro...
# 1     ✨Soft triple weave fabric with a velvet-lik...
#
#                                          ingredients platform
# 0  Cyclopentasiloxane, trimethylsiloxysilicate, s...  Walmart
# 1                                                NaN  Walmart

# %% [markdown]
# ##### 9. Combine Datasets

# %%
df = pd.concat([walmart, amazon], ignore_index=True)

# Check counts
print(df["platform"].value_counts())
print("Total rows:", df.shape[0])
# Out:
# platform
# Amazon     1066
# Walmart    1000
# Name: count, dtype: int64
# Total rows: 2066

# %%
df.isnull().sum()
# Out:
# discount         1112
# categories        168
# url                36
# initial_price     740
# brand             116
# rating             80
# final_price       512
# currency           36
# upc               968
# description       303
# ingredients      1916
# platform            0
# dtype: int64

# %% [markdown]
# ##### 10. Handling Missing Values

# %%
# Convert to correct types
df['rating'] = pd.to_numeric(df['rating'], errors='coerce')
df['final_price'] = pd.to_numeric(df['final_price'], errors='coerce')
df['initial_price'] = pd.to_numeric(df['initial_price'], errors='coerce')
df['description'] = df['description'].astype(str)
df['categories'] = df['categories'].astype(str)

# Fill missing values safely
df['discount'] = (
    df['discount']
    .astype(str)                  # ensure it's string
    .str.replace('$', '', regex=False)  # remove $
)
df['discount'] = pd.to_numeric(df['discount'], errors='coerce')
df['discount'] = df['discount'].fillna(0)
df['rating'] = df['rating'].fillna(df['rating'].mean())
df['brand'] = df['brand'].fillna('Unknown')
df['final_price'] = df['final_price'].fillna(df['final_price'].median())
df['currency'] = df['currency'].fillna('USD')
df['initial_price'] = df['initial_price'].fillna(df['final_price'])
df['description'] = df['description'].fillna('No description available')
# Removed zero rating. rating is starting with 1 and ends with 5
df.loc[df['rating'] == 0, 'rating'] = 1.0

# Drop unnecessary columns safely
df = df.drop(columns=['ingredients', 'upc', 'url'], errors='ignore')

# Check missing values
df.isnull().sum()
df['discount'].head(4)
# Out:
# 0     0.00
# 1    22.92
# 2     4.75
# 3    22.00
# Name: discount, dtype: float64

# %% [markdown]
# ##### 11. Handling Outliers for Walmart and Amazon

# %%
amazon_df = df[df['platform'] == 'Amazon']
walmart_df = df[df['platform'] == 'Walmart']

#  rating
q1 = amazon_df['rating'].quantile(0.25)
q3 = amazon_df['rating'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr

outliers = amazon_df[(amazon_df['rating'] < lower_bound) | (amazon_df['rating'] > upper_bound)]
print("Amazon rating outliers:\n", outliers)

q1 = walmart_df['rating'].quantile(0.25)
q3 = walmart_df['rating'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = walmart_df[(walmart_df['rating'] < lower_bound) | (walmart_df['rating'] > upper_bound)]
print("Walmart rating outliers:\n", outliers)
# final_price
q1 = amazon_df['final_price'].quantile(0.25)
q3 = amazon_df['final_price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = amazon_df[(amazon_df['final_price'] < lower_bound) | (amazon_df['final_price'] > upper_bound)]
print("Amazon final_price outliers:\n", outliers)
q1 = walmart_df['final_price'].quantile(0.25)
q3 = walmart_df['final_price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = walmart_df[(walmart_df['final_price'] < lower_bound) | (walmart_df['final_price'] > upper_bound)]
print("Walmart final_price outliers:\n", outliers)
# initial_price
q1 = amazon_df['initial_price'].quantile(0.25)
q3 = amazon_df['initial_price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = amazon_df[(amazon_df['initial_price'] < lower_bound) | (amazon_df['initial_price'] > upper_bound)]
print("Amazon initial_price outliers:\n", outliers)
q1 = walmart_df['initial_price'].quantile(0.25)
q3 = walmart_df['initial_price'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = walmart_df[(walmart_df['initial_price'] < lower_bound) | (walmart_df['initial_price'] > upper_bound)]
print("Walmart initial_price outliers:\n", outliers.shape)

#  Only outliers in walmart rating seem okay.
# No need to remove from df as they are valid data points.
# Out:
# Amazon rating outliers:
#  Empty DataFrame
# Columns: [discount, categories, initial_price, brand, rating, final_price, currency, description, platform]
# Index: []
# Walmart rating outliers:
#       discount                                         categories  \
# 16       2.00  ["Clothing","Womens Clothing","Womens Activewe...
# 29       0.59  ["Clothing","Womens Clothing","Womens Bras, Pa...
# 55       3.99  ["Clothing","Womens Plus","Plus Size Activewea...
# 71       0.80  ["Clothing","Womens Clothing","Womens Pants","...
# 76      19.10  ["Premium Beauty","Premium Fragrance","Premium...
# ..        ...                                                ...
# 960      4.00  ["Clothing","Womens Clothing","Womens Swimsuit...
# 962      2.30  ["Clothing","Womens Clothing","Womens Dresses"...
# 981     11.80  ["Clothing","Mens Clothing","Mens Sweaters","M...
# 990      0.90  ["Sports & Outdoors","Sports","Tennis & Racque...
# 997      3.00  ["Clothing","Shoes","Womens Shoes","Womens San...
#
#      initial_price             brand  rating  final_price currency  \
# 16           16.99            Aiyino     3.0        15.00      USD
# 29            1.58             ITSUN     1.3         0.99      USD
# 55           10.35          Ruimatai     1.8         6.36      USD
# 71            6.59            PNTUTB     3.0         5.79      USD
# 76           84.00      Ralph Lauren     3.1        64.90      USD
# ..             ...               ...     ...          ...      ...
# 960          19.99             HAWEE     3.0        16.00      USD
# 962           9.59  Follure Clothing     3.0         7.29      USD
# 981          19.99            Ussuma     1.0         8.19      USD
# 990           7.79            PNTUTB     3.0         6.89      USD
# 997          19.99      Alpine Swiss     3.4        17.00      USD
#
#                                            description platform
# 16      Top A+ MATERIAL- Polyester/Spandex. Smooth ...  Walmart
# 29   Women Sexy Lace Lingerie Set Strappy Bra and P...  Walmart
# 55      Style: Casual   Pattern Type: Plain   Seaso...  Walmart
# 71   Product information:    Gender: Women/Female/G...  Walmart
# 76   Polo Double Black Eau De Toilette Spray 4.2 Oz...  Walmart
# ..                                                 ...      ...
# 960  Description     82% Nylon, 18% Spandex     Str...  Walmart
# 962  Please read the size chart in the Description ...  Walmart
# 981     Material：These Mens Cardigan Sweaters, Mens...  Walmart
# 990  Product information:    Gender: Women/Female/G...  Walmart
# 997  FREE SHIPPING  Katie Outdoor Flip Flops&nbsp;B...  Walmart
#
# [74 rows x 9 columns]
# Amazon final_price outliers:
#        discount                                         categories  \
# 1004       0.0  ["Arts, Crafts & Sewing","Printmaking","Heat P...
# 1006       0.0   ["Home & Kitchen","Wall Art","Posters & Prints"]
# 1011       0.0  ["Clothing, Shoes & Jewelry","Men","Clothing",...
# 1015       0.0  ["Clothing, Shoes & Jewelry","Boys","Clothing"...
# 1017       0.0   ["Home & Kitchen","Wall Art","Posters & Prints"]
# ...        ...                                                ...
# 2058       0.0  ["Books","Children's Books","Geography & Cultu...
# 2059       0.0  ["Clothing, Shoes & Jewelry","Costumes & Acces...
# 2060       0.0  ["Clothing, Shoes & Jewelry","Boys","Clothing"...
# 2063       0.0  ["Home & Kitchen","Bedding","Sheets & Pillowca...
# 2064       0.0  ["Home & Kitchen","Kitchen & Dining","Dining &...
#
#       initial_price                         brand  rating  final_price  \
# 1004          14.49                       PATIKIL     2.4        14.49
# 1006          29.97                        Custom     1.0        29.97
# 1011           4.39  long sleeve pullover for men     1.0         4.39
# 1015          32.89                       Generic     1.0        32.89
# 1017          49.99          Trends International     5.0        49.99
# ...             ...                           ...     ...          ...
# 2058          31.36              Louise Spilsbury     1.0        31.36
# 2059          16.99                    Quaelystic     3.0        16.99
# 2060           8.89                       Generic     5.0         8.89
# 2063         112.99                     CottonFly     1.0       112.99
# 2064          15.97                        3dRose     1.0        15.97
#
#      currency                                        description platform
# 1004      USD  About this item Color: Dark Red; Material: PU ...   Amazon
# 1006      USD  Oil painting stlye posters can be of various t...   Amazon
# 1011      USD  Men's Slim Fit Shirt Long Sleeve Quick Dry Und...   Amazon
# 1015      USD  toddler boy jogger pants light brown boyfriend...   Amazon
# 1017      USD  Trends International framed posters are everyo...   Amazon
# ...       ...                                                ...      ...
# 2058      USD  Give young readers a deeper look into the viol...   Amazon
# 2059      USD                                                nan   Amazon
# 2060      USD                                                nan   Amazon
# 2063      USD  Best 4 PCS Bedding Set 100% Organic Cotton 800...   Amazon
# 2064      USD  About this item OPTIONS: Available in 11 and 1...   Amazon
#
# [413 rows x 9 columns]
# Walmart final_price outliers:
#       discount                                         categories  \
# 12      55.53  ["Clothing","Shoes","Mens Shoes","Mens Wide Sh...
# 32     323.00  ["Home","Furniture","Kitchen & Dining Furnitur...
# 37     135.00  ["Patio & Garden","Outdoor Shade","Patio Umbre...
# 39     115.00  ["Patio & Garden","Patio Furniture","Shop All ...
# 42      10.30  ["Home","Bedding","Bed Sheets & Pillowcases","...
# ..        ...                                                ...
# 972    288.00  ["Patio & Garden","Sheds & Outdoor Storage","S...
# 973     18.40  ["Home","Decor","Curtains & Window Treatments"...
# 988     39.05  ["Clothing","Shoes","Womens Shoes","Womens Boo...
# 993     46.02  ["Home","Furniture","Bedroom Furniture","Beds"...
# 994     15.00  ["Clothing","Shoes","Womens Shoes","Womens Boo...
#
#      initial_price               brand  rating  final_price currency  \
# 12          178.53        Georgia Boot     4.5        123.0      USD
# 32          562.99             AUSTUFF     4.4        240.0      USD
# 37          339.99        WestinTrends     4.2        205.0      USD
# 39          469.99             UDPATIO     4.6        355.0      USD
# 42          102.99              Amay's     5.0         92.7      USD
# ..             ...                 ...     ...          ...      ...
# 972         447.99                Aiho     4.3        160.0      USD
# 973          92.00              Amay's     5.0         73.6      USD
# 988         129.00           Dearfoams     4.3         90.0      USD
# 993         135.99             Renwick     4.6         90.0      USD
# 994          85.00  JOURNEE COLLECTION     4.4         70.0      USD
#
#                                            description platform
# 12   These boots are about comfort and quality. The...  Walmart
# 32          👍【360-degree Swivel Function】This barst...  Walmart
# 37      The offset patio umbrella can provide you w...  Walmart
# 39               ❤️ ➤【360 DEGREE &amp; ROCKING SWIV...  Walmart
# 42      The 4-PCs Sheet Set includes :- 1-PC Flat S...  Walmart
# ..                                                 ...      ...
# 972  Aiho 6 x 4 FT Storage&nbsp; with Sliding and L...  Walmart
# 973     PACKAGE CONTAINS : Grey 60 Inch Wide by 84 ...  Walmart
# 988  Say hello to the perfect suede fold-over winte...  Walmart
# 993              Renwick Graceful Scroll Metal Bed ...  Walmart
# 994  Update your closet with fashion designs from J...  Walmart
#
# [99 rows x 9 columns]
# Amazon initial_price outliers:
#        discount                                         categories  \
# 1004       0.0  ["Arts, Crafts & Sewing","Printmaking","Heat P...
# 1006       0.0   ["Home & Kitchen","Wall Art","Posters & Prints"]
# 1011       0.0  ["Clothing, Shoes & Jewelry","Men","Clothing",...
# 1015       0.0  ["Clothing, Shoes & Jewelry","Boys","Clothing"...
# 1017       0.0   ["Home & Kitchen","Wall Art","Posters & Prints"]
# ...        ...                                                ...
# 2058       0.0  ["Books","Children's Books","Geography & Cultu...
# 2059       0.0  ["Clothing, Shoes & Jewelry","Costumes & Acces...
# 2060       0.0  ["Clothing, Shoes & Jewelry","Boys","Clothing"...
# 2063       0.0  ["Home & Kitchen","Bedding","Sheets & Pillowca...
# 2064       0.0  ["Home & Kitchen","Kitchen & Dining","Dining &...
#
#       initial_price                         brand  rating  final_price  \
# 1004          14.49                       PATIKIL     2.4        14.49
# 1006          29.97                        Custom     1.0        29.97
# 1011           4.39  long sleeve pullover for men     1.0         4.39
# 1015          32.89                       Generic     1.0        32.89
# 1017          49.99          Trends International     5.0        49.99
# ...             ...                           ...     ...          ...
# 2058          31.36              Louise Spilsbury     1.0        31.36
# 2059          16.99                    Quaelystic     3.0        16.99
# 2060           8.89                       Generic     5.0         8.89
# 2063         112.99                     CottonFly     1.0       112.99
# 2064          15.97                        3dRose     1.0        15.97
#
#      currency                                        description platform
# 1004      USD  About this item Color: Dark Red; Material: PU ...   Amazon
# 1006      USD  Oil painting stlye posters can be of various t...   Amazon
# 1011      USD  Men's Slim Fit Shirt Long Sleeve Quick Dry Und...   Amazon
# 1015      USD  toddler boy jogger pants light brown boyfriend...   Amazon
# 1017      USD  Trends International framed posters are everyo...   Amazon
# ...       ...                                                ...      ...
# 2058      USD  Give young readers a deeper look into the viol...   Amazon
# 2059      USD                                                nan   Amazon
# 2060      USD                                                nan   Amazon
# 2063      USD  Best 4 PCS Bedding Set 100% Organic Cotton 800...   Amazon
# 2064      USD  About this item OPTIONS: Available in 11 and 1...   Amazon
#
# [395 rows x 9 columns]
# Walmart initial_price outliers:
#  (88, 9)

# %%
(df['rating'] == 0).sum()
# Out:
# np.int64(0)

# %% [markdown]
# ##### 11. Analysis

# %%
# Shape of dataset
df.shape
# Column information
df.info()
# First few rows
df.head()
df.describe()
df.groupby('platform').describe()
df.isnull().sum()
# Percentage of missing values
(df.isnull().sum() / len(df)) * 100
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2066 entries, 0 to 2065
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   discount       2066 non-null   float64
#  1   categories     2066 non-null   object
#  2   initial_price  2066 non-null   float64
#  3   brand          2066 non-null   object
#  4   rating         2066 non-null   float64
#  5   final_price    2066 non-null   float64
#  6   currency       2066 non-null   object
#  7   description    2066 non-null   object
#  8   platform       2066 non-null   object
# dtypes: float64(4), object(5)
# memory usage: 145.4+ KB
# discount         0.0
# categories       0.0
# initial_price    0.0
# brand            0.0
# rating           0.0
# final_price      0.0
# currency         0.0
# description      0.0
# platform         0.0
# dtype: float64

# %% [markdown]
# ##### 12. Universal Analysis

# %%
df['rating'].value_counts()
# Out:
# rating
# 1.000000    596
# 5.000000    223
# 4.600000    141
# 4.400000    131
# 4.500000    127
# 3.060338    112
# 4.700000    110
# 4.200000    100
# 4.300000     93
# 4.800000     85
# 4.000000     60
# 4.100000     46
# 3.000000     36
# 3.700000     34
# 3.800000     34
# 4.900000     32
# 3.900000     26
# 3.600000     18
# 3.300000     12
# 3.500000     10
# 2.000000      8
# 3.400000      6
# 2.800000      4
# 3.200000      4
# 2.500000      3
# 3.100000      3
# 2.900000      2
# 2.300000      2
# 2.700000      2
# 1.800000      1
# 1.300000      1
# 2.400000      1
# 1.500000      1
# 1.700000      1
# 2.600000      1
# Name: count, dtype: int64

# %%
df['rating'].describe()
# Out:
# count    2066.000000
# mean        3.334297
# std         1.581401
# min         1.000000
# 25%         1.000000
# 50%         4.200000
# 75%         4.600000
# max         5.000000
# Name: rating, dtype: float64

# %%
df['final_price'].describe()
# Out:
# count    2066.000000
# mean       45.501332
# std       148.598315
# min         0.100000
# 25%        16.000000
# 50%        22.000000
# 75%        30.000000
# max      3310.000000
# Name: final_price, dtype: float64

# %%
df['final_price'].value_counts().head(4)
# Out:
# final_price
# 22.00    551
# 15.00     68
# 20.00     54
# 9.99      33
# Name: count, dtype: int64

# %%
df['discount'].describe()
# Out:
# count    2066.000000
# mean        9.290503
# std        45.641570
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         6.195000
# max       958.000000
# Name: discount, dtype: float64

# %% [markdown]
# ##### 13.Bivariate Analysis

# %%
# Platform vs price analysis
df.groupby('platform')['final_price'].mean()
# Out:
# platform
# Amazon     52.535358
# Walmart    38.003060
# Name: final_price, dtype: float64

# %%
# Plateform vs rating analysis
df.groupby('platform')['rating'].mean()
# Out:
# platform
# Amazon     2.391987
# Walmart    4.338800
# Name: rating, dtype: float64

# %%
# Rating vs discount analysis
df.groupby('rating')['discount'].mean()
# Out:
# rating
# 1.000000     0.213456
# 1.300000     0.590000
# 1.500000     0.000000
# 1.700000     0.000000
# 1.800000     3.990000
# 2.000000     1.195000
# 2.300000     1.500000
# 2.400000     0.000000
# 2.500000     6.000000
# 2.600000     0.000000
# 2.700000     2.000000
# 2.800000     1.200000
# 2.900000    17.000000
# 3.000000     5.175833
# 3.060338     0.000000
# 3.100000     6.566667
# 3.200000     3.820000
# 3.300000     5.427500
# 3.400000     3.181667
# 3.500000     5.360000
# 3.600000     3.967222
# 3.700000    10.641471
# 3.800000     2.675000
# 3.900000     4.626923
# 4.000000    13.320000
# 4.100000     7.046087
# 4.200000     8.391800
# 4.300000    14.737742
# 4.400000    15.619924
# 4.500000    13.695118
# 4.600000    33.470496
# 4.700000    19.749545
# 4.800000    13.404118
# 4.900000    38.564375
# 5.000000     7.182152
# Name: discount, dtype: float64

# %%
# Brand vs Price (Top Brands)
df.groupby('brand')['final_price'].mean().sort_values(ascending=False).head(10)
# Out:
# brand
# DIAMOND DOMAIN        3310.000
# Zayan Rugs            2240.000
# 三科 光平                 2001.000
# EternalDia            1696.000
# Westintrends          1690.000
# Clara Pucci           1581.865
# KarParts360           1110.880
# Men's Fine Jewelry    1049.990
# Lovechild Masaba       950.000
# Chief                  791.700
# Name: final_price, dtype: float64

# %% [markdown]
# ##### 14. Multivariate Analysis

# %%
# Pivot Table for Platform and currency
pd.pivot_table(
    df,
    values='final_price',
    index='platform',
    columns='currency',
    aggfunc='mean'
).head()
# Out:
# currency   each Rick has his own Morty     CAD     EUR     GPB    INR     JPY  \
# platform
# Amazon                            22.0  22.275  30.572  25.826  709.0  2001.0
# Walmart                            NaN     NaN     NaN     NaN    NaN     NaN
#
# currency        USD  color"":""64# Teal + Blackout Lining""  \
# platform
# Amazon    50.619451                                    22.0
# Walmart   38.003060                                     NaN
#
# currency  color"":""Blue Marble""  color"":""Dark Heather Grey""  ...  \
# platform                                                          ...
# Amazon                       22.0                           22.0  ...
# Walmart                       NaN                            NaN  ...
#
# currency  {""asin"":""B085DNDK2V""  {""asin"":""B08GPRJ65F""  \
# platform
# Amazon                        22.0                      22.0
# Walmart                        NaN                       NaN
#
# currency  {""asin"":""B0CQGH4FDL""  {""asin"":""B0D6FMHYX4""  \
# platform
# Amazon                        22.0                      22.0
# Walmart                        NaN                       NaN
#
# currency  {""asin"":""B0D6VNMS1Y""  {""asin"":""B0DP9P4GNH""  \
# platform
# Amazon                        22.0                      22.0
# Walmart                        NaN                       NaN
#
# currency  {""asin"":""B0DVVFPGZM""  {""asin"":""B0FK1TC9KJ""  \
# platform
# Amazon                        22.0                      22.0
# Walmart                        NaN                       NaN
#
# currency  {""asin"":""B0G8YK3LMY""  {""asin"":""MC_Assembly_1#B07537PB9W""
# platform
# Amazon                        22.0                                    22.0
# Walmart                        NaN                                     NaN
#
# [2 rows x 35 columns]

# %%
# Plvot table for platform, categories, and final price
pd.pivot_table(
    df,
    values='final_price',
    index='platform',
    columns='categories',
    aggfunc='mean'
).head()
# Out:
# categories   Green""   daughter of Jerry and Beth  \
# platform
# Amazon          22.0                         22.0
# Walmart          NaN                          NaN
#
# categories  ["Appliances","Parts & Accessories","Refrigerator Parts & Accessories","Handles"]  \
# platform
# Amazon                                                  40.99
# Walmart                                                   NaN
#
# categories  ["Appliances","Parts & Accessories","Refrigerator Parts & Accessories","Motors"]  \
# platform
# Amazon                                                  15.99
# Walmart                                                   NaN
#
# categories  ["Appliances","Parts & Accessories"]  \
# platform
# Amazon                                      8.99
# Walmart                                      NaN
#
# categories  ["Arts Crafts & Sewing","Fabric","Shop All Fabric"]  \
# platform
# Amazon                                                    NaN
# Walmart                                                  10.8
#
# categories  ["Arts Crafts & Sewing","Scrapbooking","Stickers"]  \
# platform
# Amazon                                                    NaN
# Walmart                                                  3.21
#
# categories  ["Arts, Crafts & Sewing","Beading & Jewelry Making","Beads & Bead Assortments"]  \
# platform
# Amazon                                                 15.995
# Walmart                                                   NaN
#
# categories  ["Arts, Crafts & Sewing","Fabric"]  \
# platform
# Amazon                                  20.992
# Walmart                                    NaN
#
# categories  ["Arts, Crafts & Sewing","Model & Hobby Building","Model Kits","Figure Kits"]  \
# platform
# Amazon                                                  10.98
# Walmart                                                   NaN
#
# categories  ...  \
# platform    ...
# Amazon      ...
# Walmart     ...
#
# categories  name"":""64# Teal + Blackout Lining 56\""W x 108\""L (Pack of 1)""  \
# platform
# Amazon                                                   22.0
# Walmart                                                   NaN
#
# categories  name"":""December Birthstone 10.25""  \
# platform
# Amazon                                      22.0
# Walmart                                      NaN
#
# categories  name"":""Men's Big and Tall Dark Heather Grey 6X Tall""  \
# platform
# Amazon                                                   22.0
# Walmart                                                   NaN
#
# categories  name"":""S (18-21 inch suitcase) Blue Marble""     nan  \
# platform
# Amazon                                                22.0  33.335
# Walmart                                                NaN     NaN
#
# categories  size"":""34\""W x 36\""L (Pack of 2)""  size"":""Medium""  \
# platform
# Amazon                                        22.0               22.0
# Walmart                                        NaN                NaN
#
# categories  size"":""Super King- 3 PC""  unit_price"":null}  \
# platform
# Amazon                             22.0                22.0
# Walmart                             NaN                 NaN
#
# categories  {""asin"":""B0FH1BWDNN""
# platform
# Amazon                          22.0
# Walmart                          NaN
#
# [2 rows x 1095 columns]

# %% [markdown]
# ##### 15. Correlation Analysis

# %%
num_cols = ['final_price','initial_price','rating','discount']

corr_matrix = df[num_cols].corr()
corr_matrix
# Out:
#                final_price  initial_price    rating  discount
# final_price       1.000000       0.969404 -0.031069  0.388557
# initial_price     0.969404       1.000000  0.011508  0.597535
# rating           -0.031069       0.011508  1.000000  0.148237
# discount          0.388557       0.597535  0.148237  1.000000

# %% [markdown]
# #### 16. Exploratory Data Analysis (EDA) – Key Insights
#
# ##### 1. Univariate Analysis (Single Variable Analysis)
# - Rating Distribution
#     * Total observations: 2066
#     * Mean rating: 3.33
#     * Median rating: 4.20
#     * Minimum rating: 1.0
#     * Maximum rating: 5.0
#
#     - Insights:
#
#         - Ratings are concentrated toward the higher range (4.0–5.0).
#
#         - The median (4.2) is higher than the mean (3.33), indicating a left-skewed distribution.
#
#         - A large number of products received a rating of 1, mainly due to replacement of missing values with 1.
#
#         - This impacts the overall average rating and slightly lowers the mean.
#
# - Final Price Distribution
#     * Mean price: $45.50
#     * Median price: $22.00
#     * Maximum price: $3310
#     * Standard deviation: 148.59
#
#     - Insights:
#
#         - Most products are priced below $30, as shown by the median.
#
#         - A small number of very expensive products increase the mean price.
#
#         - High standard deviation indicates wide price variation.
#
#         - The dataset contains several high-priced outliers.
#
# - Discount Distribution
#     * Mean discount: $9.29
#     * Median discount: $0.00
#     * Maximum discount: $958
#     * 50% of products have no discount
#
#     - Insights:
#
#         - More than half of the products do not offer any discount.
#
#         - Discounts are highly skewed, with a few products having very large discounts.
#
#         - Most discounts are concentrated in the lower range (0–6).
#
# - Most Common Prices
#     * Top occurring prices:
#         * $22.00 → 551 products
#         * $15.00 → 68 products
#         * $20.00 → 54 products
#         * $9.99 → 33 products
#
#     - Insights:
#
#         - Pricing is clustered around popular psychological price points.
#
#         - $22 and $20 appear to be dominant pricing strategies.
#
# ##### 2. Bivariate Analysis (Relationship Between Two Variables)
#
# - Platform vs Final Price
#
# | Platform | Average Price    |
# |----------|------------------|
# | Amazon   | $52.54           |
# | Walmart  | $38.00           |
#
# - Insights:
#
#     - Amazon products are generally more expensive than Walmart products.
#
#     - Walmart focuses more on budget-friendly items.
#
#     - Amazon appears to have a wider premium product range.
#
# - Platform vs Rating
# | Platform | Average Rating   |
# |----------|------------------|
# | Amazon   | 2.39             |
# | Walmart  | 4.34             |
#
# - Insights:
#
#     - Walmart products receive significantly higher ratings.
#
#     - Amazon’s lower average rating is influenced by many replaced missing values.
#
#     - Customer satisfaction appears higher on Walmart.
#
# - Rating vs Discount
#
#     - Products with higher ratings (4.5–5.0) tend to have moderate to high discounts.
#
#     - Some low-rated products also receive discounts.
#
# - Insights:
#
#     - Discounts are not strongly dependent on ratings.
#
#     - Well-rated products are still discounted, likely for promotional purposes.
#
# - Brand vs Final Price
#
#     - Top expensive brands:
#
#         - DIAMOND DOMAIN → $3310
#
#         - Zayan Rugs → $2240
#
#         - EternalDia → $1696
#
#         - Westintrends → $1690
#
# Insights:
#
# - Certain premium brands dominate the high-price segment.
#
# - Brand reputation strongly influences pricing.
#
# ##### 3. Multivariate Analysis (Multiple Variables)
#
# - Platform and Currency
#
#     - Amazon products appear in multiple currencies (USD, INR, EUR, JPY, etc.).
#
#     - Walmart products are mainly in USD.
#
# - Insights:
#
#     - Amazon has wider international presence.
#
#     - Walmart’s dataset is more region-focused.
#
# - Platform, Category, and Price
#
#     - Amazon covers a wide range of categories such as electronics, fashion, home, and accessories.
#
#     - Walmart has fewer categories represented.
#
# - Insights:
#
#     - Amazon has greater product diversity.
#
#     - Walmart focuses on selected categories.
#
# ##### 4. Correlation Analysis
# |   Variables                         |   Correlation                           |
# |-------------------------------------|-----------------------------------------|
# |   Final – Initial	Price             |   0.97                                  |
# |   Initial – Discount	              |   0.60                                  |
# |   Final – Discount	              |   0.39                                  |
# |   Rating – Price	                  |   -0.03                                 |
# |   Rating – Discount                 |   0.15	                                |
#
# - Key Observations
#     - Final Price vs Initial Price (0.97)
#
#         * Very strong positive correlation.
#
#         * Final prices closely follow original prices.
#
#         * Discounts are usually proportional.
#
#     - Initial Price vs Discount (0.60)
#
#         * Higher-priced products receive higher discounts.
#
#         * Expensive items are often promoted more.
#
#     - Rating vs Price (-0.03)
#
#         * Almost no relationship.
#
#         * Expensive products are not necessarily better rated.
#
#     - Rating vs Discount (0.15)
#
#         - Weak positive relationship.
#
#         - Discounts have minimal impact on ratings.
#
# ##### 5. Overall Findings and Business Insights
#
# Key Findings
#
# - Most products are low to moderately priced, with a few extreme outliers.
#
# - Amazon products are generally more expensive than Walmart.
#
# - Walmart products have higher average ratings.
#
# - More than half of the products have no discount.
#
# - Price is strongly influenced by brand and original price.
#
# - Ratings are weakly related to price and discount.
#
# Limitations
#
# - Missing ratings were replaced with 1, which may bias results.
#
# - Discount values show extreme outliers.
#
# - Some categorical fields contain noisy or unstructured data.

# %% [markdown]
# 16. Save Cleaned DataFrame to CSV

# %%
# Save cleaned dataset
df.to_csv("cleaned_amazon_walmart_data.csv", index=False)

print("CSV file saved successfully!")
# Out:
# CSV file saved successfully!
